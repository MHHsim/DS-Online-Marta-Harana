# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre conceptos básicos de Matplotlib, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos las tienes ya, intenta no mirarlos de primeras pero no dejes de hacerlo cuando hayas terminado por si te pudieran aportar.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import matplotlib.pyplot as plt
plt.style.use("tableau-colorblind10")
import numpy as np

# %%
x =np.linspace(0,10,100)

plt.plot(x, np.sin(x))
plt.xlim(0, 10)
plt.ylim(-1,1)
# Out:
# (-1.0, 1.0)

# %%
x = np.linspace(0, 10, 100)

# 1ª fila, 1ª columna
plt.subplot(2, 3, 1)
plt.plot(x, np.sin(x), "r")
plt.title("Seno")

# 1ª fila, 2ª columna
plt.subplot(2, 3, 2)
plt.plot(x, np.cos(x), "g")
plt.title("Coseno")

# 1ª fila, 3ª columna
plt.subplot(2, 3, 3)
plt.plot(x, np.tan(x), "y")
plt.title("Tangente")

# 2ª fila, 1ª columna
plt.subplot(2, 3, 4)
plt.plot(x, np.exp(x/5))
plt.title("Exp")

# 2ª fila, 2ª columna
plt.subplot(2, 3, 5)
plt.plot(x, np.log(x+1))
plt.title("Log")

# 2ª fila, 3ª columna
plt.subplot(2, 3, 6)
plt.plot(x, np.sqrt(x))
plt.title("Raíz")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ejercicio 1
#
# Construye la siguiente figura con dos subplots utilizando el estilo MATLAB (es decir plt.\<funcion\>, no usando objetos `Axes`)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0, 10, 100)

# 1ª fila, 1ª columna
plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))
plt.title("Seno")

# 1ª fila, 2ª columna
plt.subplot(1, 2, 2)
plt.plot(x, np.cos(x))
plt.title("Coseno")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ejercicio 2
#
# Reproduce la imagen de la figura usando tres subplots en una columna, utilizando objetos `Axes`. Las dos primeras son las funciones anteriores y la tercera es la tangente (np.tan)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0, 10, 100)

# 1ª fila, 1ª columna
plt.subplot(3, 1, 1)
plt.plot(x, np.sin(x), "r")
plt.title("Seno")

# 2ª fila, 1ª columna
plt.subplot(3, 1, 2)
plt.plot(x, np.cos(x), "g")
plt.title("Coseno")

# 3ª fila, 1ª columna
plt.subplot(3, 1, 3)
plt.plot(x, np.tan(x))
plt.title("Tangente")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(3, 1, sharex="col", sharey="row")

# Seno
ax[0].plot(x, np.sin(x), color="red")
ax[0].set_title("Seno")

# Coseno
ax[1].plot(x, np.cos(x), color="green")
ax[1].set_title("Coseno")

# Tangente
ax[2].plot(x, np.tan(x), color="blue")
ax[2].set_title("Tangente")

plt.tight_layout()
plt.show();

# %% [markdown]
# ### Ejercicio 3: Ajuste de Colores y Estilos de Línea
#
# Modifica la primera figura para que se muestre de la siguiente manera

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(1, 2)

# Subplot 1: magenta, punteado
ax[0].plot(x, np.sin(x/2), color="magenta", linestyle="--")
ax[0].set_title("Seno")
ax[0].set_xlim(0,10)
ax[0].set_ylim(-1, 1)

# Subplot 2: cian, guion‑punto
ax[1].plot(x, np.cos(x), color="cyan", linestyle="-.")
ax[1].set_title("Coseno")

plt.tight_layout()
plt.show()

# %%
x = np.linspace(0, 10, 100)

fig, ax = plt.subplots(1, 2, figsize=(10, 4))

ax[0].plot(x, np.sin(x), color="magenta", linestyle="--")
ax[0].set_title("Seno")
ax[0].set_ylim(1, -1)
ax[0].set_xlim(0, 10)

ax[1].plot(x, np.cos(x/2), color="cyan", linestyle="-.")
ax[1].set_title("Coseno")
ax[1].set_ylim(1, -1)
ax[1].set_xlim(0, 10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ejercicio 4
#
# Reproduce la figura siguiente. Recuerda que las funciones seno hiperbólico y coseno hiperbólico se obtienen así:
# * np.sinh, seno hiperbólico;
# * np.cosh, coseno hiperbólico;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(2, 1, sharex="col", sharey="row")

# Seno
ax[0].plot(x, np.sinh(x), color="red")
ax[0].set_title("Seno Hiperbólico")

# Coseno
ax[1].plot(x, np.cosh(x), color="blue")
ax[1].set_title("Coseno Hiperbólico")


plt.tight_layout()
plt.show();

# %% [markdown]
# ### Ejercicio 5: Ajustando el Espaciado de Subplots
#
# Reproduce la siguiente figura con cuatro subplots, ajusta el espaciado entre los subplots para evitar la superosición (tal y como ves en la figura), emplea `subplots_adjust` y los parámetros hspace y wspace.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0, 10, 100)

fig, ax = plt.subplots(2, 2)

# Seno
ax[0, 0].plot(x, np.sin(x))

# Coseno
ax[0, 1].plot(x, np.cos(x))

# Tangente
ax[1, 0].plot(x, np.tan(x))
ax[1, 0].set_ylim(-40, 20)   # para que no explote

# Logaritmo
ax[1, 1].plot(x, np.log(x + 1))


# Ajuste del espaciado
fig.subplots_adjust(
    hspace=0.5,   # espacio vertical
    wspace=0.5    # espacio horizontal
)

plt.show()

# %% [markdown]
# ### Ejercicio 6:
#
# Reproduce la figura siguiente empleando sólo el estilo MATLAB (plt.\<funcion>\) y creando solo el contenido de los dos primeros gráficos (fila 1). Luego usa el estilo con métodos (objetos `axes`) para añadir el tercer gráfico.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1ª fila, 1ª columna
plt.subplot(2, 1, 1)
plt.plot(x, np.cos(x))
plt.title("Raiz cuadrada y coseno")
plt.plot(x, np.sqrt(x), label = "Raiz cuadrada", color = "orange")
plt.legend();

# 1ª fila, 2ª columna
plt.subplot(2, 1, 2)
plt.plot(x, np.sin(x))
plt.title("Seno");

# %% [markdown]
# ### Ejercicio 7
#
# Para terminar, reproduce la imagen de la figura

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8,4))

plt.plot(
    x, y,
    marker="o",
    markersize=8,
    markerfacecolor="yellow",
    markeredgecolor="blue",
    linewidth=4

)

plt.title("Ejemplo de Marcadores")
plt.ylim(-1.1, 1.1)

plt.show()
