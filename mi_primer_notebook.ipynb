# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# Hola Mundo

# %%
import os
print(os.path.exists(os.getenv("GOOGLE_APPLICATION_CREDENTIALS")))
print(os.getenv("GOOGLE_APPLICATION_CREDENTIALS"))

# %%
from google.cloud import bigquery
from dotenv import load_dotenv
import os

load_dotenv()

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

project_id = os.getenv("GCP_PROJECT_ID")
dataset_id = os.getenv("BQ_DATASET_ID")

client = bigquery.Client(project=project_id)

# %%
tables = client.list_tables("shopnow")
for t in tables:
    print(t.table_id)

# %%
GOOGLE_APPLICATION_CREDENTIALS=C:\\Users\\Usuario\\Desktop\\Curso_DS\\clave_json\\tc-novarix-data.json
GCP_PROJECT_ID=tc-novarix-data
BQ_DATASET_ID=shopnow

# %%
from faker import Faker
import pandas as pd
import random

fake = Faker()
rows = []

for _ in range(1000):
    rows.append({
        "customer_id": fake.uuid4(),
        "name": fake.name(),
        "email": fake.email(),
        "phone": fake.phone_number(),
        "address": fake.address().replace("\n", ", "),
        "created_at": fake.date_time_between(start_date="-2y", end_date="now")
    })

df = pd.DataFrame(rows)
df.to_csv("customers_fake.csv", index=False)

# %%
df
# Out:
#                               customer_id              name  \
# 0    eeee91fb-9d85-4dd6-a19f-aef723cbe50b    Jennifer Smith
# 1    550acca0-8e7f-42c2-909c-97bbcddf7931    Ashley Parsons
# 2    eb3df228-5833-4736-bff0-10d8c50354f6  Caroline Johnson
# 3    69fe474f-13e4-43fc-8b9d-0e17f193c19d  Elizabeth Garcia
# 4    e43f8c1e-6e9e-4334-9f63-14eb91ecca16     Cynthia Smith
# ..                                    ...               ...
# 995  cc8d0b9c-f02e-4880-8fa5-1a7005edbf55   Jason Carpenter
# 996  4b413129-afe8-47a2-80d0-a710ee6ac37d      Austin Jones
# 997  ca2c0e87-6477-4854-83a4-e15cd9c394a9   Elizabeth Kline
# 998  4e8ee3ec-e015-478a-9b81-5420f065714b   Thomas Franklin
# 999  58b93620-6667-40e2-9677-f3dc9540cf83     Jeremy Miller
#
#                          email                  phone  \
# 0      dwilliamson@example.com           864-935-0474
# 1    harriscynthia@example.net    (763)598-2709x88691
# 2          james16@example.org       993.254.3112x595
# 3             akim@example.org      491-937-2289x7625
# 4        michael32@example.org      (892)349-2609x858
# ..                         ...                    ...
# 995       justin19@example.com     638-666-6622x00428
# 996    lunastephen@example.com           577-774-9751
# 997       hannah02@example.org  +1-681-781-3271x94698
# 998      rebecca00@example.org  001-697-407-7454x0452
# 999    wrightsarah@example.net      (586)788-0795x133
#
#                                                address          created_at
# 0               177 Harris Key, Matthewhaven, UT 24971 2024-08-14 06:43:50
# 1    866 Camacho Plaza Suite 125, North Kyle, MI 62986 2024-05-18 18:57:48
# 2    5430 Cynthia Mission Apt. 037, Loveborough, MD... 2026-03-27 21:39:51
# 3           6623 Rachel Islands, Lake Morgan, MI 23109 2024-11-10 23:14:34
# 4         450 John Extension, Williamborough, OK 69882 2025-05-02 16:54:44
# ..                                                 ...                 ...
# 995             3208 Diaz Keys, Mitchellstad, IL 79374 2025-12-08 06:47:18
# 996            97542 Joseph Spurs, Lake Sean, SC 99865 2024-12-01 06:50:13
# 997          414 Harris Shoal, South Yolanda, VI 27635 2025-09-01 14:50:16
# 998        187 Miller Shoals, Lake Stephanie, AS 38367 2025-11-02 23:26:04
# 999                   Unit 6422 Box 5080, DPO AA 30884 2024-10-27 02:32:14
#
# [1000 rows x 6 columns]
