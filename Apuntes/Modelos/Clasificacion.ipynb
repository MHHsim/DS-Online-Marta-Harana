# %% [markdown]
# ### IMPORT Modelos Clasificación

# %%
# --- CORE ---
import numpy as np
import pandas as pd

# --- MODELOS LINEALES ---
from sklearn.linear_model import LogisticRegression

# --- ÁRBOLES Y ENSEMBLES ---
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# --- KNN ---
from sklearn.neighbors import KNeighborsClassifier

# --- SVM ---
from sklearn.svm import SVC

# --- BOOSTING ---
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# --- VALIDACIÓN ---
from sklearn.model_selection import StratifiedKFold

# --- MÉTRICAS ---
from sklearn.model_selection import cross_val_score
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    classification_report,
    confusion_matrix
)

# %% [markdown]
# ### BaseLines para todos los modelos (hay que elegir 4 o 5 como mucho para probar)

# %%
cv_clf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

modelos_clasificacion = {
    # --- LINEALES ---
    "Logistic Regression": LogisticRegression(
        max_iter=1000,
        random_state=42
    ),

    # --- ÁRBOLES ---
    "Decision Tree": DecisionTreeClassifier(
        max_depth=None,     # baseline: sin limitar profundidad
        random_state=42
    ),

    "Random Forest": RandomForestClassifier(
        n_estimators=100,
        max_depth=3,
        random_state=42,
        n_jobs=-1
    ),

    # --- KNN ---
    "KNN": KNeighborsClassifier(
        n_neighbors=5,      # baseline clásico
        weights="uniform",  # sin ponderación por distancia
        n_jobs=-1
    ),

    # --- SVM ---
    "SVM": SVC(
        kernel="rbf",       # baseline estándar
        C=1.0,              # valor por defecto
        gamma="scale",      # valor por defecto
        probability=True,   # para poder usar predict_proba si lo necesitas
        random_state=42
    ),

    # --- BOOSTING ---
    "XGBoost": XGBClassifier(
        n_estimators=100,
        learning_rate=0.1,
        max_depth=3,
        random_state=42,
        n_jobs=-1,
        verbosity=0
    ),

    "LightGBM": LGBMClassifier(
        n_estimators=100,
        learning_rate=0.1,
        num_leaves=31,
        random_state=42,
        n_jobs=-1,
        verbose=-1
    ),

    "CatBoost": CatBoostClassifier(
        iterations=100,         # equivalente a n_estimators
        learning_rate=0.1,
        depth=3,
        random_state=42,
        verbose=False           # silencia logs
    )
}

print("=" * 55)
print("BASELINE CLASIFICACIÓN")
print("=" * 55)
for nombre, modelo in modelos_clasificacion.items():
    scores = cross_val_score(modelo, X, y, cv=cv_clf, scoring="accuracy") # accuracy
                                                                          # recall
                                                                          # recall_macro
                                                                          # balanced_accuracy
                                                                          # f1_scores
    print(f"{nombre:<22} accuracy: {scores.mean():.4f} ± {scores.std():.4f}")

# %%
print("=" * 55)
print("BASELINE CLASIFICACIÓN")
print("=" * 55)
for nombre, modelo in modelos_clasificacion.items():
    scores = cross_val_score(modelo, X, y, cv=cv_clf, scoring="accuracy")
    print(f"{nombre:<22} accuracy: {scores.mean():.4f} ± {scores.std():.4f}")
