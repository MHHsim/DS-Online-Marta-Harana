# %%
import pandas as pd


df = pd.read_csv("data/Mercancias-RESUMEN.csv", sep=";")
df
# Out:
#        Año Autoridad Portuaria    Operacion           Transito  \
# 0     1962            A Coruña  Desembarque  Incluido tránsito
# 1     1962            A Coruña     Embarque  Incluido tránsito
# 2     1962            Alicante  Desembarque  Incluido tránsito
# 3     1962            Alicante     Embarque  Incluido tránsito
# 4     1962             Almería  Desembarque  Incluido tránsito
# ...    ...                 ...          ...                ...
# 5820  2024          Vilagarcía  Desembarque  Incluido tránsito
# 5821  2024          Vilagarcía  Desembarque      Solo tránsito
# 5822  2024          Vilagarcía     Embarque  Incluido tránsito
# 5823  2024          Vilagarcía     Embarque      Solo tránsito
# 5824  2024          Vilagarcía   Transbordo  Incluido tránsito
#
#      Graneles líquidos Graneles sólidos Mercancía general convencional  \
# 0              204.092          147.137                        110.979
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5825 entries, 0 to 5824
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Año                              5825 non-null   datetime64[us]
#  1   Autoridad Portuaria              5825 non-null   str
#  2   Operacion                        5825 non-null   str
#  3   Transito                         5825 non-null   str
#  4   Graneles líquidos                5825 non-null   str
#  5   Graneles sólidos                 5825 non-null   str
#  6   Mercancía general convencional   5825 non-null   str
#  7   Mercancía general en contenedor  5825 non-null   str
#  8   Mercancía general                5825 non-null   str
#  9   Pesca                            5825 non-null   float64
#  10  Avituallamiento                  5825 non-null   str
#  11  Tráfico interior                 5825 non-null   str
# ...

# %%
df["Año"] = pd.to_datetime(df["Año"], format="%Y")

# %%
df_filtrado = df[df["Año"].dt.year.isin([2023, 2024])]
df_filtrado
# Out:
#             Año Autoridad Portuaria    Operacion           Transito  \
# 5545 2023-01-01            A Coruña  Desembarque  Incluido tránsito
# 5546 2023-01-01            A Coruña  Desembarque      Solo tránsito
# 5547 2023-01-01            A Coruña     Embarque  Incluido tránsito
# 5548 2023-01-01            A Coruña     Embarque      Solo tránsito
# 5549 2023-01-01            A Coruña   Transbordo  Incluido tránsito
# ...         ...                 ...          ...                ...
# 5820 2024-01-01          Vilagarcía  Desembarque  Incluido tránsito
# 5821 2024-01-01          Vilagarcía  Desembarque      Solo tránsito
# 5822 2024-01-01          Vilagarcía     Embarque  Incluido tránsito
# 5823 2024-01-01          Vilagarcía     Embarque      Solo tránsito
# 5824 2024-01-01          Vilagarcía   Transbordo  Incluido tránsito
#
#      Graneles líquidos Graneles sólidos Mercancía general convencional  \
# 5545         5.724.746        3.465.159                        429.305
# ...

# %%
df_filtrado.drop(columns=["Unnamed: 13", "Unnamed: 14", "Unnamed: 15"])
# Out:
#             Año Autoridad Portuaria    Operacion           Transito  \
# 5545 2023-01-01            A Coruña  Desembarque  Incluido tránsito
# 5546 2023-01-01            A Coruña  Desembarque      Solo tránsito
# 5547 2023-01-01            A Coruña     Embarque  Incluido tránsito
# 5548 2023-01-01            A Coruña     Embarque      Solo tránsito
# 5549 2023-01-01            A Coruña   Transbordo  Incluido tránsito
# ...         ...                 ...          ...                ...
# 5820 2024-01-01          Vilagarcía  Desembarque  Incluido tránsito
# 5821 2024-01-01          Vilagarcía  Desembarque      Solo tránsito
# 5822 2024-01-01          Vilagarcía     Embarque  Incluido tránsito
# 5823 2024-01-01          Vilagarcía     Embarque      Solo tránsito
# 5824 2024-01-01          Vilagarcía   Transbordo  Incluido tránsito
#
#      Graneles líquidos Graneles sólidos Mercancía general convencional  \
# 5545         5.724.746        3.465.159                        429.305
# ...

# %%
df_filtrado["Autoridad Portuaria"].value_counts()
# Out:
# Autoridad Portuaria
# A Coruña                     10
# Alicante                     10
# Almería                      10
# Avilés                       10
# Bahía de Algeciras           10
# Bahía de Cádiz               10
# Baleares                     10
# Barcelona                    10
# Bilbao                       10
# Cartagena                    10
# Castellón                    10
# Ceuta                        10
# Ferrol-San Cibrao            10
# Gijón                        10
# Huelva                       10
# Las Palmas                   10
# Marín y Ría de Pontevedra    10
# Melilla                      10
# Motril                       10
# Málaga                       10
# Pasaia                       10
# Santa Cruz de Tenerife       10
# Santander                    10
# Sevilla                      10
# Tarragona                    10
# Valencia                     10
# Vigo                         10
# Vilagarcía                   10
# ...

# %%
df_bahiadecadiz = df_filtrado[df_filtrado["Autoridad Portuaria"] == "Bahía de Cádiz"]
df_bahiadecadiz
# Out:
#             Año Autoridad Portuaria    Operacion           Transito  \
# 5570 2023-01-01      Bahía de Cádiz  Desembarque  Incluido tránsito
# 5571 2023-01-01      Bahía de Cádiz  Desembarque      Solo tránsito
# 5572 2023-01-01      Bahía de Cádiz     Embarque  Incluido tránsito
# 5573 2023-01-01      Bahía de Cádiz     Embarque      Solo tránsito
# 5574 2023-01-01      Bahía de Cádiz   Transbordo  Incluido tránsito
# 5710 2024-01-01      Bahía de Cádiz  Desembarque  Incluido tránsito
# 5711 2024-01-01      Bahía de Cádiz  Desembarque      Solo tránsito
# 5712 2024-01-01      Bahía de Cádiz     Embarque  Incluido tránsito
# 5713 2024-01-01      Bahía de Cádiz     Embarque      Solo tránsito
# 5714 2024-01-01      Bahía de Cádiz   Transbordo  Incluido tránsito
#
#      Graneles líquidos Graneles sólidos Mercancía general convencional  \
# 5570           625.117        1.868.405                        360.751
# 5571           563.549           26.110                          3.554
# ...
